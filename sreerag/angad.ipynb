# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_csv('Marketing-Monk-1.0-Ads-23-Jul-202123-Aug-2024.csv',header=1)

# %%
dataset.head()
# Out:
#    2023-09-14  2024-08-23  New Leads ad  inactive          New Leads ad set  \
# 0  2023-09-14  2024-08-23          meme  inactive                 marketing
# 1  2023-09-14  2024-08-23          meme  inactive         digital marketing
# 2  2023-09-14  2024-08-23          meme  inactive  marketing manager narrow
# 3  2023-09-14  2024-08-23  New Leads ad  inactive          New Leads ad set
# 4  2023-09-14  2024-08-23  New Leads ad  inactive          New Leads ad set
#
#    0  ABSOLUTE_OCPM  800  Daily 2023-09-15T02:14:24+0530  ...     2  \
# 0  0  ABSOLUTE_OCPM  200  Daily                        0  ...  43.0
# 1  0  ABSOLUTE_OCPM  200  Daily                        0  ...  74.0
# 2  0  ABSOLUTE_OCPM  200  Daily                        0  ...  48.0
# 3  0  ABSOLUTE_OCPM  800  Daily                        0  ...   NaN
# 4  0  ABSOLUTE_OCPM  800  Daily                        0  ...  28.0
#
#    actions:offsite_conversion.custom.273944142071330  2301  2857        225  \
# 0  actions:offsite_conversion.custom.965885947820970  1797  3263   2.363721
# 1  actions:offsite_conversion.custom.965885947820970  1765  3183   1.417973
# 2  actions:offsite_conversion.custom.965885947820970  1192  2473   2.046458
# 3                                                NaN  4271  4634        NaN
# 4                      conversions:subscribe_website  7526  8009  22.203214
#
#    - -.1 -.2     450  நடப்பிலுள்ள
# 0  -   -   -  101.64  நடப்பிலுள்ள
# 1  -   -   -  104.93  நடப்பிலுள்ள
# 2  -   -   -   98.23  நடப்பிலுள்ள
# 3  -   -   -  289.80  நடப்பிலுள்ள
# 4  -   -   -  621.69  நடப்பிலுள்ள
#
# [5 rows x 21 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 21 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   2023-09-14                                         282 non-null    object
#  1   2024-08-23                                         282 non-null    object
#  2   New Leads ad                                       282 non-null    object
#  3   inactive                                           282 non-null    object
#  4   New Leads ad set                                   282 non-null    object
#  5   0                                                  282 non-null    int64
#  6   ABSOLUTE_OCPM                                      282 non-null    object
#  7   800                                                282 non-null    object
#  8   Daily                                              282 non-null    object
#  9   2023-09-15T02:14:24+0530                           282 non-null    object
#  10  7-day click or 1-day view                          282 non-null    object
#  11  2                                                  242 non-null    float64
#  12  actions:offsite_conversion.custom.273944142071330  242 non-null    object
#  13  2301                                               282 non-null    int64
#  14  2857                                               282 non-null    int64
#  15  225                                                242 non-null    float64
#  16  -                                                  282 non-null    object
#  17  -.1                                                282 non-null    object
#  18  -.2                                                282 non-null    object
#  19  450                                                282 non-null    float64
#  20  நடப்பிலுள்ள                                        282 non-null    object
# dtypes: float64(3), int64(3), object(15)
# memory usage: 46.4+ KB

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#      2023-09-14  2024-08-23  \
# 3    2023-09-14  2024-08-23
# 19   2023-09-14  2024-08-23
# 33   2023-09-14  2024-08-23
# 34   2023-09-14  2024-08-23
# 35   2023-09-14  2024-08-23
# 36   2023-09-14  2024-08-23
# 37   2023-09-14  2024-08-23
# 38   2023-09-14  2024-08-23
# 39   2023-09-14  2024-08-23
# 40   2023-09-14  2024-08-23
# 41   2023-09-14  2024-08-23
# 42   2023-09-14  2024-08-23
# 49   2023-09-14  2024-08-23
# 51   2023-09-14  2024-08-23
# 56   2023-09-14  2024-08-23
# 57   2023-09-14  2024-08-23
# 58   2023-09-14  2024-08-23
# 59   2023-09-14  2024-08-23
# 60   2023-09-14  2024-08-23
# 72   2023-09-14  2024-08-23
# 123  2023-09-14  2024-08-23
# 128  2023-09-14  2024-08-23
# 135  2023-09-14  2024-08-23
# 137  2023-09-14  2024-08-23
# 138  2023-09-14  2024-08-23
# 143  2023-09-14  2024-08-23
# 146  2023-09-14  2024-08-23
# 156  2023-09-14  2024-08-23
# 160  2023-09-14  2024-08-23
# 212  2023-09-14  2024-08-23
# 213  2023-09-14  2024-08-23
# 214  2023-09-14  2024-08-23
# 230  2023-09-14  2024-08-23
# 257  2023-09-14  2024-08-23
# 259  2023-09-14  2024-08-23
# 263  2023-09-14  2024-08-23
# 266  2023-09-14  2024-08-23
# 268  2023-09-14  2024-08-23
# 271  2023-09-14  2024-08-23
# 276  2023-09-14  2024-08-23
#
#                                           New Leads ad        inactive  \
# 3                                         New Leads ad        inactive
# 19                               New Leads ad – Copy 1        inactive
# 33                                        New Leads ad        inactive
# 34                                        New Leads ad        inactive
# 35                                 New Leads ad – Copy        inactive
# 36                               New Leads ad – Copy 2        inactive
# 37                                        New Leads ad        inactive
# 38                               New Leads ad – Copy 2        inactive
# 39                                 New Leads ad – Copy        inactive
# 40                                        New Leads ad        inactive
# 41                               New Leads ad – Copy 2        inactive
# 42                                 New Leads ad – Copy        inactive
# 49                                        New Leads ad        inactive
# 51                                        New Leads ad        inactive
# 56                                        New Leads ad        inactive
# 57                                        New Leads ad        inactive
# 58                                        New Leads ad        inactive
# 59                                        New Leads ad        inactive
# 60                                        New Leads ad        inactive
# 72                                        New Leads ad        inactive
# 123                                New Leads ad – Copy        inactive
# 128                                New Leads ad – Copy        inactive
# 135                                       New Leads ad        inactive
# 137                                New Leads ad – Copy        inactive
# 138                                New Leads ad – Copy        inactive
# 143                                       New Leads ad        inactive
# 146  Marketing Professionals - Age: 24+ - Top Citie...        archived
# 156                                New Leads ad – Copy        inactive
# 160                                New Leads ad – Copy        inactive
# 212                                       New Leads Ad        archived
# 213                                       New Leads Ad        archived
# 214                                       New Leads Ad        archived
# 230                                       New Leads Ad        inactive
# 257                              MM_Motion_Ad_Facebook        inactive
# 259                                    UGC_Video_Ad_Fb          active
# 263                               Dynamic_Static_Ad_Fb  not_delivering
# 266                              Motion(B)_Video_Ad_FB  not_delivering
# 268                              Motion(C)_Video_Ad_FB  not_delivering
# 271                                Reddit_Static_Ad_Fb  not_delivering
# 276                             MM_Fevicol_Ad_Facebook  not_delivering
#
#               New Leads ad set  0  ABSOLUTE_OCPM                    800  \
# 3             New Leads ad set  0  ABSOLUTE_OCPM                    800
# 19            New Leads ad set  0  ABSOLUTE_OCPM  Using campaign budget
# 33   New Leads ad set – Copy 2  0  ABSOLUTE_OCPM                    200
# 34            New Leads ad set  0  ABSOLUTE_OCPM                    200
# 35            New Leads ad set  0  ABSOLUTE_OCPM                    200
# 36            New Leads ad set  0  ABSOLUTE_OCPM                    200
# 37     New Leads ad set – Copy  0  ABSOLUTE_OCPM                    200
# 38     New Leads ad set – Copy  0  ABSOLUTE_OCPM                    200
# 39     New Leads ad set – Copy  0  ABSOLUTE_OCPM                    200
# 40     New Leads ad set – Copy  0  ABSOLUTE_OCPM                    200
# 41     New Leads ad set – Copy  0  ABSOLUTE_OCPM                    200
# 42     New Leads ad set – Copy  0  ABSOLUTE_OCPM                    200
# 49            New Leads ad set  8  ABSOLUTE_OCPM                    800
# 51            New Leads ad set  8  ABSOLUTE_OCPM                    800
# 56   New Leads ad set – Copy 2  0  ABSOLUTE_OCPM                    200
# 57            New Leads ad set  0  ABSOLUTE_OCPM                    200
# 58     New Leads ad set – Copy  0  ABSOLUTE_OCPM                    200
# 59   New Leads ad set – Copy 2  0  ABSOLUTE_OCPM                    200
# 60     New Leads ad set – Copy  0  ABSOLUTE_OCPM                    200
# 72     New Leads ad set – Copy  0  ABSOLUTE_OCPM                    400
# 123    New Leads ad set – Copy  0  ABSOLUTE_OCPM                    200
# 128  New Leads ad set – Copy 2  0  ABSOLUTE_OCPM                   1200
# 135           New Leads ad set  0  ABSOLUTE_OCPM                    400
# 137  New Leads ad set – Copy 2  0  ABSOLUTE_OCPM                   1800
# 138    New Leads ad set – Copy  0  ABSOLUTE_OCPM                    600
# 143  New Leads ad set – Copy 2  0  ABSOLUTE_OCPM                    400
# 146           New Leads ad set  0  ABSOLUTE_OCPM                   1000
# 156           New Leads ad set  0  ABSOLUTE_OCPM                    800
# 160    New Leads ad set – Copy  0  ABSOLUTE_OCPM                   1600
# 212           New Leads Ad Set  0  ABSOLUTE_OCPM                    800
# 213    New Leads Ad Set - Copy  0  ABSOLUTE_OCPM                    800
# 214  New Leads Ad Set - Copy 2  0  ABSOLUTE_OCPM                    800
# 230        New Leads Ad Set_fb  0  ABSOLUTE_OCPM                    800
# 257   MM_Motion_Adset_Facebook  0  ABSOLUTE_OCPM  Using campaign budget
# 259         UGC_Video_Adset_Fb  0  ABSOLUTE_OCPM  Using campaign budget
# 263    Dynamic_Static_Adset_Fb  0  ABSOLUTE_OCPM  Using campaign budget
# 266   Motion(B)_Video_Adset_FB  0  ABSOLUTE_OCPM  Using campaign budget
# 268   Motion(C)_Video_Adset_FB  0  ABSOLUTE_OCPM  Using campaign budget
# 271     Reddit_Static_Adset_Fb  0  ABSOLUTE_OCPM  Using campaign budget
# 276  MM_Fevicol_Adset_Facebook  0  ABSOLUTE_OCPM  Using campaign budget
#
#      Daily  2023-09-15T02:14:24+0530  ...   2  \
# 3    Daily                         0  ... NaN
# 19       0                         0  ... NaN
# 33   Daily  2023-11-02T13:44:09+0530  ... NaN
# 34   Daily                         0  ... NaN
# 35   Daily                         0  ... NaN
# 36   Daily                         0  ... NaN
# 37   Daily                         0  ... NaN
# 38   Daily                         0  ... NaN
# 39   Daily                         0  ... NaN
# 40   Daily                         0  ... NaN
# 41   Daily                         0  ... NaN
# 42   Daily                         0  ... NaN
# 49   Daily                         0  ... NaN
# 51   Daily                         0  ... NaN
# 56   Daily                         0  ... NaN
# 57   Daily                         0  ... NaN
# 58   Daily                         0  ... NaN
# 59   Daily                         0  ... NaN
# 60   Daily                         0  ... NaN
# 72   Daily                         0  ... NaN
# 123  Daily                         0  ... NaN
# 128  Daily                         0  ... NaN
# 135  Daily                         0  ... NaN
# 137  Daily                         0  ... NaN
# 138  Daily                         0  ... NaN
# 143  Daily  2024-01-17T23:30:33+0530  ... NaN
# 146  Daily                         0  ... NaN
# 156  Daily                         0  ... NaN
# 160  Daily  2024-01-27T18:04:12+0530  ... NaN
# 212  Daily                         0  ... NaN
# 213  Daily                         0  ... NaN
# 214  Daily                         0  ... NaN
# 230  Daily                         0  ... NaN
# 257      0                         0  ... NaN
# 259      0                         0  ... NaN
# 263      0                         0  ... NaN
# 266      0                         0  ... NaN
# 268      0                         0  ... NaN
# 271      0                         0  ... NaN
# 276      0                         0  ... NaN
#
#      actions:offsite_conversion.custom.273944142071330  2301  2857  225  -  \
# 3                                                  NaN  4271  4634  NaN  -
# 19                                                 NaN    51    51  NaN  -
# 33                                                 NaN   615   639  NaN  -
# 34                                                 NaN   501   508  NaN  -
# 35                                                 NaN    25    25  NaN  -
# 36                                                 NaN   220   232  NaN  -
# 37                                                 NaN   517   534  NaN  -
# 38                                                 NaN   259   276  NaN  -
# 39                                                 NaN     6     8  NaN  -
# 40                                                 NaN   162   164  NaN  -
# 41                                                 NaN   569   621  NaN  -
# 42                                                 NaN    67    69  NaN  -
# 49                                                 NaN    17    17  NaN  -
# 51                                                 NaN   267   271  NaN  -
# 56                                                 NaN  2340  2492  NaN  -
# 57                                                 NaN   737   835  NaN  -
# 58                                                 NaN   753   881  NaN  -
# 59                                                 NaN   676   803  NaN  -
# 60                                                 NaN   986  1150  NaN  -
# 72                                                 NaN   419   436  NaN  -
# 123                                                NaN   278   299  NaN  -
# 128                                                NaN    39    41  NaN  -
# 135                                                NaN   108   110  NaN  -
# 137                                                NaN   502   524  NaN  -
# 138                                                NaN    29    30  NaN  -
# 143                                                NaN   114   119  NaN  -
# 146                                                NaN   920   967  NaN  -
# 156                                                NaN    71    79  NaN  -
# 160                                                NaN   683   720  NaN  -
# 212                                                NaN   458   463  NaN  -
# 213                                                NaN   496   504  NaN  -
# 214                                                NaN   158   170  NaN  -
# 230                                                NaN  1326  1530  NaN  -
# 257                                                NaN    13    19  NaN  -
# 259                                                NaN    28    29  NaN  -
# 263                                                NaN   205   253  NaN  -
# 266                                                NaN   244   276  NaN  -
# 268                                                NaN   223   277  NaN  -
# 271                                                NaN   491   633  NaN  -
# 276                                                NaN   229   276  NaN  -
#
#     -.1 -.2     450  நடப்பிலுள்ள
# 3     -   -  289.80  நடப்பிலுள்ள
# 19    -   -    2.38  நடப்பிலுள்ள
# 33    -   -   65.02  நடப்பிலுள்ள
# 34    -   -   44.14  நடப்பிலுள்ள
# 35    -   -    1.91  நடப்பிலுள்ள
# 36    -   -   32.26  நடப்பிலுள்ள
# 37    -   -   39.79  நடப்பிலுள்ள
# 38    -   -   37.91  நடப்பிலுள்ள
# 39    -   -    0.12  நடப்பிலுள்ள
# 40    -   -   12.02  நடப்பிலுள்ள
# 41    -   -   65.81  நடப்பிலுள்ள
# 42    -   -    4.31  நடப்பிலுள்ள
# 49    -   -    0.44  நடப்பிலுள்ள
# 51    -   -    6.89  நடப்பிலுள்ள
# 56    -   -  335.05  நடப்பிலுள்ள
# 57    -   -  183.45  நடப்பிலுள்ள
# 58    -   -  186.26  நடப்பிலுள்ள
# 59    -   -  193.36  நடப்பிலுள்ள
# 60    -   -  187.19  நடப்பிலுள்ள
# 72    -   -   76.37  நடப்பிலுள்ள
# 123   -   -   20.55  நடப்பிலுள்ள
# 128   -   -    2.81  நடப்பிலுள்ள
# 135   -   -    6.99  நடப்பிலுள்ள
# 137   -   -   38.49  நடப்பிலுள்ள
# 138   -   -    0.66  நடப்பிலுள்ள
# 143   -   -    4.27  நடப்பிலுள்ள
# 146   -   -  117.43  நடப்பிலுள்ள
# 156   -   -    1.14  நடப்பிலுள்ள
# 160   -   -   27.43  நடப்பிலுள்ள
# 212   -   -   44.47  நடப்பிலுள்ள
# 213   -   -   45.85  நடப்பிலுள்ள
# 214   -   -   53.14  நடப்பிலுள்ள
# 230   -   -  210.45  நடப்பிலுள்ள
# 257   -   -    1.24  நடப்பிலுள்ள
# 259   -   -    1.18  நடப்பிலுள்ள
# 263   -   -   19.45  நடப்பிலுள்ள
# 266   -   -   17.71  நடப்பிலுள்ள
# 268   -   -   14.77  நடப்பிலுள்ள
# 271   -   -   31.29  நடப்பிலுள்ள
# 276   -   -   14.54  நடப்பிலுள்ள
#
# [40 rows x 21 columns]

# %%
plt.style.use('seaborn-v0_8-colorblind')
dataset.hist(bins=50,figsize=(20,15))
plt.show()

# %%
dataset.isnull().sum()
# Out:
# 2023-09-14                                            0
# 2024-08-23                                            0
# New Leads ad                                          0
# inactive                                              0
# New Leads ad set                                      0
# 0                                                     0
# ABSOLUTE_OCPM                                         0
# 800                                                   0
# Daily                                                 0
# 2023-09-15T02:14:24+0530                              0
# 7-day click or 1-day view                             0
# 2                                                    40
# actions:offsite_conversion.custom.273944142071330    40
# 2301                                                  0
# 2857                                                  0
# 225                                                  40
# -                                                     0
# -.1                                                   0
# -.2                                                   0
# 450                                                   0
# நடப்பிலுள்ள                                           0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['2023-09-14', '2024-08-23', 'New Leads ad', 'inactive',
#        'New Leads ad set', '0', 'ABSOLUTE_OCPM', '800', 'Daily',
#        '2023-09-15T02:14:24+0530', '7-day click or 1-day view', '2',
#        'actions:offsite_conversion.custom.273944142071330', '2301', '2857',
#        '225', '-', '-.1', '-.2', '450', 'நடப்பிலுள்ள'],
#       dtype='object')

# %%
x=dataset.drop('New Leads ad',axis=1)
y=dataset['New Leads ad']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((211, 20), (71, 20))

# %%
x_train.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 x_train.corr()
#
# File c:\code\venv\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\code\venv\lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\code\venv\lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\code\venv\lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '2023-09-14'

# %%
plt.figure(figsize=(12,10))
corr=x_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 plt.figure(figsize=(12,10))
# ----> 2 corr=x_train.corr()
#       3 sns.heatmap(corr,annot=True)
#
# File c:\code\venv\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\code\venv\lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\code\venv\lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\code\venv\lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '2023-09-14'
